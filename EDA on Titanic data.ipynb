# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import File

# %%
df=pd.read_csv('titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Basic Information about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 398          399         0       2
# 323          324         1       2
# 642          643         0       3
# 619          620         0       2
# 60            61         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 398                                   Pain, Dr. Alfred    male  23.0      0
# 323  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  female  22.0      1
# 642                      Skoog, Miss. Margit Elizabeth  female   2.0      3
# 619                                Gavey, Mr. Lawrence    male  26.0      0
# 60                               Sirayanian, Mr. Orsen    male  22.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 398      0  244278  10.5000   NaN        S
# 323      1  248738  29.0000   NaN        S
# 642      2  347088  27.9000   NaN        S
# 619      0   31028  10.5000   NaN        S
# 60       0    2669   7.2292   NaN        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # Drop the unnecessary columns

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.drop('SibSp', axis=1, inplace=True)

# %%
df.shape
# Out:
# (891, 10)

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  Parch  Ticket   Fare  \
# 0          False     False   False  False  False  False  False   False  False
# 1          False     False   False  False  False  False  False   False  False
# 2          False     False   False  False  False  False  False   False  False
# 3          False     False   False  False  False  False  False   False  False
# 4          False     False   False  False  False  False  False   False  False
# ..           ...       ...     ...    ...    ...    ...    ...     ...    ...
# 886        False     False   False  False  False  False  False   False  False
# 887        False     False   False  False  False  False  False   False  False
# 888        False     False   False  False  False   True  False   False  False
# 889        False     False   False  False  False  False  False   False  False
# 890        False     False   False  False  False  False  False   False  False
#
#      Embarked
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 886     False
# 887     False
# 888     False
# 889     False
# 890     False
#
# [891 rows x 10 columns]

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
#
#                                                  Name     Sex   Age  Parch  \
# 0                             Braund, Mr. Owen Harris    male  22.0      0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      2
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      5
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      1
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
#
#               Ticket     Fare Embarked
# 0          A/5 21171   7.2500        S
# 1           PC 17599  71.2833        C
# 2   STON/O2. 3101282   7.9250        S
# 3             113803  53.1000        S
# 4             373450   8.0500        S
# 6              17463  51.8625        S
# 7             349909  21.0750        S
# 8             347742  11.1333        S
# 9             237736  30.0708        C
# 10           PP 9549  16.7000        S
# 11            113783  26.5500        S
# 12         A/5. 2151   8.0500        S
# 13            347082  31.2750        S
# 14            350406   7.8542        S
# 15            248706  16.0000        S
# 16            382652  29.1250        Q
# 18            345763  18.0000        S
# 20            239865  26.0000        S
# 21            248698  13.0000        S
# 22            330923   8.0292        Q

# %% [markdown]
# # Correlation

# %%
df.corr=df.corr()
df.corr
# Out:
#              PassengerId  Survived    Pclass       Age     Parch      Fare
# PassengerId     1.000000  0.029526 -0.035609  0.033681 -0.011672  0.009655
# Survived        0.029526  1.000000 -0.356462 -0.082446  0.095265  0.266100
# Pclass         -0.035609 -0.356462  1.000000 -0.365902  0.023666 -0.552893
# Age             0.033681 -0.082446 -0.365902  1.000000 -0.187896  0.093143
# Parch          -0.011672  0.095265  0.023666 -0.187896  1.000000  0.206624
# Fare            0.009655  0.266100 -0.552893  0.093143  0.206624  1.000000

# %% [markdown]
# # Visualizing the data

# %%
sns.heatmap(df.corr)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr, cmap='YlOrRd', annot=True)

# %%
df['Survived'].plot.box()

# %%
df['Fare'].plot.box()

# %%
df['Parch'].plot.box()

# %%
df.plot(kind='box', subplots=True, layout=(2,3), figsize=(10,6))
# Out:
# PassengerId       AxesSubplot(0.125,0.536818;0.227941x0.343182)
# Survived       AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# Pclass         AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# Age                  AxesSubplot(0.125,0.125;0.227941x0.343182)
# Parch             AxesSubplot(0.398529,0.125;0.227941x0.343182)
# Fare              AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Fare'])

# %%
sns.distplot(df['Age'])

# %%
sns.distplot(df['Survived'])

# %%
df.plot(kind='kde', subplots=True, layout=(2,3), figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002292A16AEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002292A2D8F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229278E2DC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002292A332508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002292A36C088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002292A3A0FC8>]],
#       dtype=object)

# %%
plt.scatter(df['Fare'], df['Survived'])

# %%
plt.scatter(df['Survived'], df['Age'])
plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Titanic Survival data')
plt.show()
